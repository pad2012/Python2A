# %%
import pandas as pd

# %%
df = pd.read_csv("http://51.91.120.89/extras/drinksbycountry.csv")
df
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %%
df.rename(columns={"total_litres_of_pure_alcohol":"total"}, inplace=True)
df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  total continent
# 0  Afghanistan              0                0              0    0.0      Asia
# 1      Albania             89              132             54    4.9    Europe
# 2      Algeria             25                0             14    0.7    Africa
# 3      Andorra            245              138            312   12.4    Europe
# 4       Angola            217               57             45    5.9    Africa

# %%
# grupowanie na podstawie kolumny 'continent'
dfg = df.groupby("continent")

# %%
dfg.size()
# Out:
# continent
# Africa           53
# Asia             44
# Europe           45
# North America    23
# Oceania          16
# South America    12
# dtype: int64

# %%
dfg.count()
# Out:
#                country  beer_servings  spirit_servings  wine_servings  total
# continent
# Africa              53             53               53             53     53
# Asia                44             44               44             44     44
# Europe              45             45               45             45     45
# North America       23             23               23             23     23
# Oceania             16             16               16             16     16
# South America       12             12               12             12     12

# %%
dfg.first()
# Out:
#                          country  beer_servings  spirit_servings  \
# continent
# Africa                   Algeria             25                0
# Asia                 Afghanistan              0                0
# Europe                   Albania             89              132
# North America  Antigua & Barbuda            102              128
# Oceania                Australia            261               72
# South America          Argentina            193               25
#
#                wine_servings  total
# continent
# Africa                    14    0.7
# Asia                       0    0.0
# Europe                    54    4.9
# North America             45    4.9
# Oceania                  212   10.4
# South America            221    8.3

# %%
dfg.mean()
# Out:
#                beer_servings  spirit_servings  wine_servings     total
# continent
# Africa             61.471698        16.339623      16.264151  3.007547
# Asia               37.045455        60.840909       9.068182  2.170455
# Europe            193.777778       132.555556     142.222222  8.617778
# North America     145.434783       165.739130      24.521739  5.995652
# Oceania            89.687500        58.437500      35.625000  3.381250
# South America     175.083333       114.750000      62.416667  6.308333

# %%
dfg.max()
# Out:
#                       country  beer_servings  spirit_servings  wine_servings  \
# continent
# Africa               Zimbabwe            376              152            233
# Asia                    Yemen            247              326            123
# Europe         United Kingdom            361              373            370
# North America             USA            285              438            100
# Oceania               Vanuatu            306              254            212
# South America       Venezuela            333              302            221
#
#                total
# continent
# Africa           9.1
# Asia            11.5
# Europe          14.4
# North America   11.9
# Oceania         10.4
# South America    8.3

# %%
dfg.median()["wine_servings"]
# Out:
# continent
# Africa             2.0
# Asia               1.0
# Europe           128.0
# North America     11.0
# Oceania            8.5
# South America     12.0
# Name: wine_servings, dtype: float64

# %%
dfg.wine_servings.median()
# Out:
# continent
# Africa             2.0
# Asia               1.0
# Europe           128.0
# North America     11.0
# Oceania            8.5
# South America     12.0
# Name: wine_servings, dtype: float64

# %%
dfg[ ["wine_servings","total"] ].median()
# Out:
#                wine_servings  total
# continent
# Africa                   2.0   2.30
# Asia                     1.0   1.20
# Europe                 128.0  10.00
# North America           11.0   6.30
# Oceania                  8.5   1.75
# South America           12.0   6.85

# %%
df1 =dfg[ ["wine_servings","total"] ].agg([pd.np.mean, pd.np.max ])
df1
# Out:
# C:\Users\kurs\AppData\Local\Temp/ipykernel_4772/565911351.py:1: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   df1 =dfg[ ["wine_servings","total"] ].agg([pd.np.mean, pd.np.max ])
#               wine_servings          total
#                        mean amax      mean  amax
# continent
# Africa            16.264151  233  3.007547   9.1
# Asia               9.068182  123  2.170455  11.5
# Europe           142.222222  370  8.617778  14.4
# North America     24.521739  100  5.995652  11.9
# Oceania           35.625000  212  3.381250  10.4
# South America     62.416667  221  6.308333   8.3

# %%
df1.columns
# Out:
# MultiIndex([('wine_servings', 'mean'),
#             ('wine_servings', 'amax'),
#             (        'total', 'mean'),
#             (        'total', 'amax')],
#            )

# %%
# rozkład danych
dfg.groups
# Out:
# {'Africa': [2, 4, 18, 22, 26, 27, 28, 29, 31, 33, 34, 38, 39, 47, 49, 53, 55, 56, 58, 62, 63, 66, 70, 71, 88, 95, 96, 97, 100, 101, 104, 107, 108, 114, 115, 117, 123, 124, 142, 148, 150, 152, 153, 158, 159, 162, 164, 172, 175, 179, 183, 191, 192], 'Asia': [0, 12, 13, 19, 24, 30, 36, 46, 77, 78, 79, 80, 82, 85, 86, 87, 90, 91, 92, 94, 102, 103, 112, 116, 119, 127, 128, 134, 137, 138, 141, 149, 154, 161, 167, 168, 169, 171, 176, 177, 181, 186, 189, 190], 'Europe': [1, 3, 7, 9, 10, 15, 16, 21, 25, 42, 44, 45, 48, 57, 60, 61, 64, 65, 67, 75, 76, 81, 83, 93, 98, 99, 105, 111, 113, 120, 126, 135, 136, 139, 140, 147, 151, 155, 156, 160, 165, 166, 170, 180, 182], 'North America': [5, 11, 14, 17, 32, 41, 43, 50, 51, 54, 68, 69, 73, 74, 84, 109, 122, 130, 143, 144, 145, 174, 184], 'Oceania': [8, 40, 59, 89, 106, 110, 118, 121, 125, 129, 131, 146, 157, 173, 178, 187], 'South America': [6, 20, 23, 35, 37, 52, 72, 132, 133, 163, 185, 188]}

# %%
df.loc[ [6, 20, 23, 35, 37, 52, 72, 132, 133, 163, 185, 188] ]
# Out:
#        country  beer_servings  spirit_servings  wine_servings  total  \
# 6    Argentina            193               25            221    8.3
# 20     Bolivia            167               41              8    3.8
# 23      Brazil            245              145             16    7.2
# 35       Chile            130              124            172    7.6
# 37    Colombia            159               76              3    4.2
# 52     Ecuador            162               74              3    4.2
# 72      Guyana             93              302              1    7.1
# 132   Paraguay            213              117             74    7.3
# 133       Peru            163              160             21    6.1
# 163   Suriname            128              178              7    5.6
# 185    Uruguay            115               35            220    6.6
# 188  Venezuela            333              100              3    7.7
#
#          continent
# 6    South America
# 20   South America
# ...

# %%
dfg.get_group("South America")
# Out:
#        country  beer_servings  spirit_servings  wine_servings  total  \
# 6    Argentina            193               25            221    8.3
# 20     Bolivia            167               41              8    3.8
# 23      Brazil            245              145             16    7.2
# 35       Chile            130              124            172    7.6
# 37    Colombia            159               76              3    4.2
# 52     Ecuador            162               74              3    4.2
# 72      Guyana             93              302              1    7.1
# 132   Paraguay            213              117             74    7.3
# 133       Peru            163              160             21    6.1
# 163   Suriname            128              178              7    5.6
# 185    Uruguay            115               35            220    6.6
# 188  Venezuela            333              100              3    7.7
#
#          continent
# 6    South America
# 20   South America
# ...

# %%
# Utwórz DF z krajów gdzie jest największe spozycie (wg. kolumny total). 
# Bierzemy po 1 kraju z najwiekszym spożyciem dla danego kontynentu

# %%
df.sort_values('total', ascending=False).groupby('continent').first()
# Out:
#                           country  beer_servings  spirit_servings  \
# continent
# Africa                    Nigeria             42                5
# Asia           Russian Federation            247              326
# Europe                    Belarus            142              373
# North America             Grenada            199              438
# Oceania                 Australia            261               72
# South America           Argentina            193               25
#
#                wine_servings  total
# continent
# Africa                     2    9.1
# Asia                      73   11.5
# Europe                    42   14.4
# North America             28   11.9
# Oceania                  212   10.4
# South America            221    8.3

# %%
df.sort_values('total', ascending=False).groupby('continent').head(3)
# Out:
#                 country  beer_servings  spirit_servings  wine_servings  total  \
# 15              Belarus            142              373             42   14.4
# 98            Lithuania            343              244             56   12.9
# 3               Andorra            245              138            312   12.4
# 68              Grenada            199              438             28   11.9
# 141  Russian Federation            247              326             73   11.5
# 8             Australia            261               72            212   10.4
# 144           St. Lucia            171              315             71   10.1
# 138         South Korea            140               16              9    9.8
# 121         New Zealand            203               79            175    9.3
# 124             Nigeria             42                5              2    9.1
# 62                Gabon            347               98             59    8.9
# ...

# %%
df.sort_values('total', ascending=False).drop_duplicates(subset='continent')
# Out:
#                 country  beer_servings  spirit_servings  wine_servings  total  \
# 15              Belarus            142              373             42   14.4
# 68              Grenada            199              438             28   11.9
# 141  Russian Federation            247              326             73   11.5
# 8             Australia            261               72            212   10.4
# 124             Nigeria             42                5              2    9.1
# 6             Argentina            193               25            221    8.3
#
#          continent
# 15          Europe
# 68   North America
# 141           Asia
# 8          Oceania
# 124         Africa
# 6    South America

# %%
df = pd.read_csv("http://51.91.120.89/extras/nba-ok.csv")
df
# Out:
#      Unnamed: 0           Name            Team  Number Position   Age Height  \
# 0             0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2
# 1             1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6
# 2             2   John Holland  Boston Celtics    30.0       SG  27.0    6-5
# 3             3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5
# 4             4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10
# ..          ...            ...             ...     ...      ...   ...    ...
# 452         452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10
# 453         453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3
# 454         454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1
# 455         455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3
# 456         456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0
#
#      Weight            College     Salary
# ...

# %%
from scipy.stats import trim_mean

# %%
def tm(x):
    return trim_mean(x, 0.1)

# %%
dfg = df.groupby("Team")

# %%
dfg["Salary"].agg(["mean", tm])
# Out:
#                                 mean            tm
# Team
# Atlanta Hawks           4.860197e+06  4.131246e+06
# Boston Celtics          3.902738e+06  3.580082e+06
# Brooklyn Nets           3.501898e+06  2.515789e+06
# Charlotte Hornets       5.222728e+06  4.973190e+06
# Chicago Bulls           5.785559e+06  5.089632e+06
# Cleveland Cavaliers     7.132579e+06  6.462938e+06
# Dallas Mavericks        4.746582e+06  4.174318e+06
# Denver Nuggets          4.008129e+06  3.547841e+06
# Detroit Pistons         4.477884e+06  3.927448e+06
# Golden State Warriors   5.924600e+06  5.621403e+06
# Houston Rockets         5.018868e+06  4.055620e+06
# Indiana Pacers          4.450122e+06  3.801537e+06
# Los Angeles Clippers    6.323643e+06  5.636500e+06
# Los Angeles Lakers      4.784695e+06  3.557334e+06
# Memphis Grizzlies       4.252827e+06  3.553930e+06
# Miami Heat              5.501045e+06  4.640226e+06
# Milwaukee Bucks         4.350220e+06  3.778621e+06
# ...

# %%
dfg.agg({
    "Age" : [min, max],
    "Salary": ["mean", tm, "median"]
})
# Out:
#                          Age              Salary
#                          min   max          mean            tm     median
# Team
# Atlanta Hawks           22.0  35.0  4.860197e+06  4.131246e+06  2854940.0
# Boston Celtics          20.0  29.0  3.902738e+06  3.580082e+06  2616975.0
# Brooklyn Nets           21.0  32.0  3.501898e+06  2.515789e+06  1335480.0
# Charlotte Hornets       21.0  31.0  5.222728e+06  4.973190e+06  4204200.0
# Chicago Bulls           21.0  35.0  5.785559e+06  5.089632e+06  2380440.0
# Cleveland Cavaliers     24.0  35.0  7.132579e+06  6.462938e+06  4950000.0
# Dallas Mavericks        22.0  37.0  4.746582e+06  4.174318e+06  3950313.0
# Denver Nuggets          20.0  36.0  4.008129e+06  3.547841e+06  2814000.0
# Detroit Pistons         20.0  36.0  4.477884e+06  3.927448e+06  2891760.0
# Golden State Warriors   20.0  33.0  5.924600e+06  5.621403e+06  3815000.0
# Houston Rockets         22.0  38.0  5.018868e+06  4.055620e+06  2288205.0
# ...
