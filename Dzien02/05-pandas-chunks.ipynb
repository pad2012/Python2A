# %%
import pandas as pd

# %%
df = pd.DataFrame()
df_gen = pd.read_csv(r"C:/Users/kurs/Downloads/sales-records.csv", chunksize=98765)
for chunk in df_gen:
    chunk = chunk.query(" `Units Sold`>=300 and `Units Sold`<=1000  ")
    df = df.append(chunk)
    print(".", end="")
# Out:
# ...........

# %%
df
# Out:
#                                    Region           Country        Item Type  \
# 2                   Australia and Oceania  Papua New Guinea             Meat
# 3                      Sub-Saharan Africa          Djibouti          Clothes
# 6                      Sub-Saharan Africa       Seychelles         Beverages
# 8                      Sub-Saharan Africa             Ghana  Office Supplies
# 15                     Sub-Saharan Africa            Uganda    Personal Care
# ...                                   ...               ...              ...
# 999914                 Sub-Saharan Africa        The Gambia        Household
# 999938                               Asia         Indonesia       Vegetables
# 999953                 Sub-Saharan Africa           Nigeria        Cosmetics
# 999956  Central America and the Caribbean       Saint Lucia        Cosmetics
# 999957  Central America and the Caribbean         Guatemala           Fruits
#
# ...

# %%
df.describe()
# Out:
#            Order ID    Units Sold    Unit Price     Unit Cost  Total Revenue  \
# count  6.974000e+04  69740.000000  69740.000000  69740.000000   69740.000000
# mean   5.494564e+08    650.132621    265.828506    187.416153  172884.136087
# std    2.597755e+08    202.527279    216.342687    175.277300  156847.733577
# min    1.000656e+08    300.000000      9.330000      6.920000    2799.000000
# 25%    3.235371e+08    474.000000    109.280000     56.670000   55412.940000
# 50%    5.497621e+08    650.000000    205.700000    117.110000  119396.500000
# 75%    7.734867e+08    825.000000    421.890000    263.330000  249646.860000
# max    9.999995e+08   1000.000000    668.270000    524.960000  668270.000000
#
#           Total Cost   Total Profit
# count   69740.000000   69740.000000
# mean   121912.246741   50971.889346
# std    125286.110668   39043.645659
# min      2076.000000     723.000000
# 25%     29596.490000   20878.000000
# 50%     72198.420000   44387.700000
# ...
